# %% [markdown]
# <a href="https://colab.research.google.com/github/ayo43/UkrainRussiaWar/blob/main/UkrainRussiaWar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob

# %%
comments = pd.read_csv('/content/filename.csv', error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
comments.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1525304179018940421  1525304179018940421  2022-05-14 02:37:09 UTC
# 1  1525304176036564992  1525304176036564992  2022-05-14 02:37:09 UTC
# 2  1525304173176049666  1525304173176049666  2022-05-14 02:37:08 UTC
# 3  1525304171779325952  1525304171779325952  2022-05-14 02:37:07 UTC
# 4  1525304167388000258  1525303681729568768  2022-05-14 02:37:06 UTC
#
#          date      time  timezone              user_id         username  \
# 0  2022-05-14  02:37:09         0  1417037325822054402  christo01098190
# 1  2022-05-14  02:37:09         0           1565703367    tianfu_kizmet
# 2  2022-05-14  02:37:08         0  1191398917151133696  aussieedddoggie
# 3  2022-05-14  02:37:07         0  1369169778019950592      fitzflyer83
# 4  2022-05-14  02:37:06         0  1224913418823458816         0xfff747
#
#                    name  place  ... geo source user_rt_id user_rt retweet_id  \
# ...

# %%
comments.iloc[:,10]
# Out:
# 0        Instruments of death, large guns, etc. should ...
# 1        Inflation in #Russia hits 17.83% in April, hig...
# 2        Ukraine news live: Russian agents 'believe Put...
# 3        Russia to Cut Electricity Supplied to Finland ...
# 4        @JungerianJihad Can't wait for you to actually...
#                                ...
# 9999     @AnonOpsSE @mfa_russia Fitting, it’s fitting h...
# 10000    So @JoeBiden @BorisJohnson @JustinTrudeau and ...
# 10001    @gingertealkp @NBA @WNBA Biden administration ...
# 10002    @MU53701477 @Yeweettoch @EerikNKross You didn'...
# 10003    Russian-occupied Georgian region #SouthOssetia...
# Name: tweet, Length: 10004, dtype: object

# %%
#!pip install textblob
TextBlob("I am a madd girl").sentiment.polarity
# Out:
# 0.0

# %%
#This is to get sum of all missing values
comments.isna().sum()
# Out:
# id                     0
# conversation_id        0
# created_at             0
# date                   0
# time                   0
# timezone               0
# user_id                0
# username               0
# name                   0
# place              10004
# tweet                  0
# language               0
# mentions               0
# urls                   0
# photos                 0
# replies_count          0
# retweets_count         0
# likes_count            0
# hashtags               0
# cashtags               0
# link                   0
# retweet                0
# quote_url           9135
# video                  0
# thumbnail           9042
# near               10004
# geo                10004
# source             10004
# user_rt_id         10004
# user_rt            10004
# retweet_id         10004
# reply_to               0
# retweet_date       10004
# translate          10004
# trans_src          10004
# trans_dest         10004
# dtype: int64

# %%
#To remove all missing value
comments.dropna(inplace=True)

# %%
comments.head()
# Out:
# Empty DataFrame
# Columns: [id, conversation_id, created_at, date, time, timezone, user_id, username, name, place, tweet, language, mentions, urls, photos, replies_count, retweets_count, likes_count, hashtags, cashtags, link, retweet, quote_url, video, thumbnail, near, geo, source, user_rt_id, user_rt, retweet_id, reply_to, retweet_date, translate, trans_src, trans_dest]
# Index: []
#
# [0 rows x 36 columns]
# ...

# %%
polarity =[]

for i in comments['tweet']:
  polarity.append(TextBlob(i).sentiment.polarity)

# %%
comments['polarity']= polarity

# %%
comments.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1525304179018940421  1525304179018940421  2022-05-14 02:37:09 UTC
# 1  1525304176036564992  1525304176036564992  2022-05-14 02:37:09 UTC
# 2  1525304173176049666  1525304173176049666  2022-05-14 02:37:08 UTC
# 3  1525304171779325952  1525304171779325952  2022-05-14 02:37:07 UTC
# 4  1525304167388000258  1525303681729568768  2022-05-14 02:37:06 UTC
#
#          date      time  timezone              user_id         username  \
# 0  2022-05-14  02:37:09         0  1417037325822054402  christo01098190
# 1  2022-05-14  02:37:09         0           1565703367    tianfu_kizmet
# 2  2022-05-14  02:37:08         0  1191398917151133696  aussieedddoggie
# 3  2022-05-14  02:37:07         0  1369169778019950592      fitzflyer83
# 4  2022-05-14  02:37:06         0  1224913418823458816         0xfff747
#
#                    name  place  ... source user_rt_id user_rt retweet_id  \
# ...

# %%
comments_positive = comments[comments['polarity']==1]

# %%
comments_positive.head()
# Out:
#                       id      conversation_id               created_at  \
# 226  1525303104710750208  1525303104710750208  2022-05-14 02:32:53 UTC
# 313  1525302699951988738  1525302699951988738  2022-05-14 02:31:17 UTC
# 337  1525302563662450690  1525302561858850817  2022-05-14 02:30:44 UTC
# 441  1525302124774854656  1525294098290286592  2022-05-14 02:28:59 UTC
# 672  1525300854890307584  1525300853409718273  2022-05-14 02:23:57 UTC
#
#            date      time  timezone              user_id       username  \
# 226  2022-05-14  02:32:53         0  1263171123002462208  prepredzonenm
# 313  2022-05-14  02:31:17         0           2927790398    bookofbrikk
# 337  2022-05-14  02:30:44         0  1268740475944669184     eco_pietro
# 441  2022-05-14  02:28:59         0  1327432171607375873      kdhunter4
# 672  2022-05-14  02:23:57         0  1268740475944669184     eco_pietro
#
#                         name  place  ... source user_rt_id user_rt retweet_id  \
# ...

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)

# %%
total_comments = ' '.join(comments_positive['tweet'])

# %%
wordcloud=WordCloud(width=1000,height=500, stopwords=stopwords).generate(total_comments)

# %%
plt.figure(figsize=(15,5))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %%
comments_negative = comments[comments['polarity']==-1]

# %%
comments_negative.head()
# Out:
#                        id      conversation_id               created_at  \
# 236   1525303010548756482  1525203529467432962  2022-05-14 02:32:31 UTC
# 442   1525302123592060928  1525302123592060928  2022-05-14 02:28:59 UTC
# 952   1525299584808890368  1525299584808890368  2022-05-14 02:18:54 UTC
# 1023  1525299233699545088  1525299233699545088  2022-05-14 02:17:30 UTC
# 1841  1525295450059948033  1525295435148951552  2022-05-14 02:02:28 UTC
#
#             date      time  timezone              user_id         username  \
# 236   2022-05-14  02:32:31         0            247619342     theansweryes
# 442   2022-05-14  02:28:59         0  1266920789015588866  marlow_watching
# 952   2022-05-14  02:18:54         0             76832524          ddcc224
# 1023  2022-05-14  02:17:30         0   931961869992161280    polizzithomas
# 1841  2022-05-14  02:02:28         0            247619342     theansweryes
#
#                      name  place  ... source user_rt_id user_rt retweet_id  \
# ...

# %%
total_comments = ' '.join(comments_negative['tweet'])

# %%
wordcloud=WordCloud(width=1000,height=500, stopwords=stopwords).generate(total_comments)

# %%
plt.figure(figsize=(15,5))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 999.5, 499.5, -0.5)
